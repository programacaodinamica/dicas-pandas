# %% [markdown]
# <a href="https://colab.research.google.com/github/programacaodinamica/dicas-pandas/blob/master/Pandas_do_ZERO_%C3%A0_An%C3%A1lise_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Está começando agora e quer aprender **pandas** para analisar de dados? Este documento reúne tudo que você precisa saber sobre Pandas.

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo("wnGsAOPKjLo", width=640)

# %% [markdown]
# # O que é Pandas?

# %% [markdown]
# ![Captura de Tela 2021-09-04 às 15.59.04.png](data:image/png;base64,...)

# %% [markdown]
# ```
# pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.
# ```
#
#
# ```
# Criada em 2008, pandas é um uma ferramenta de código aberto para manipulação e análise de dados, rápida poderosa, flexível e fácil de usar. Fonte: [Site oficial](https://pandas.pydata.org/)
# ```

# %% [markdown]
# # Por que Pandas?

# %% [markdown]
# > Python com pandas está em uso em uma ampla variedade de domínios acadêmicos e comerciais , incluindo Finanças, Neurociência, Economia, Estatística, Publicidade, Web Analytics e muito mais. [Ecossitema Pandas](https://pandas.pydata.org/community/ecosystem.html)
#
# * Altamente otimizado para desempenho , com caminhos de código críticos escritos em Cython ou C.
#
# * Eficiente para manipulação de dados com indexação integrada;
#
# * Ferramentas para ler e gravar dados entre estruturas de dados na memória e diferentes formatos: CSV e arquivos de texto, Microsoft Excel, bancos de dados SQL e o formato rápido HDF5;
#
# * Alinhamento inteligente de dados e manuseio integrado de dados perdidos : obtenha alinhamento automático baseado em rótulo em cálculos e manipule facilmente dados confusos em uma forma ordenada;
#
# * Remodelagem e rotação flexível de conjuntos de dados;
#
# * As colunas podem ser inseridas e excluídas de estruturas de dados para mutabilidade de tamanho;
#
# * Agregação e junção de conjuntos de dados de alto desempenho;
#
# [Saiba mais](https://pandas.pydata.org/about/index.html)

# %% [markdown]
# # Como aprender Pandas?

# %% [markdown]
# 1. Documentação!!!
#   * [pandas.pydata.org](https://pandas.pydata.org/)
#   * [10 minutes to pandas](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html#minutes-to-pandas)
#   * [FAQ](https://pandas.pydata.org/pandas-docs/stable/user_guide/gotchas.html#frequently-asked-questions-faq)
#   * [Pandas: powerful Python data analysis
# toolkit](https://pandas.pydata.org/pandas-docs/version/1.3.1/pandas.pdf)
#
# 2. Livros
#   * [Python para Análise de Dados |  Python for Data Analysis - Wes McKinney](https://www.amazon.com.br/Python-Para-An%C3%A1lise-Dados-Tratamento/dp/8575226479/ref=sr_1_1?dchild=1&qid=1630780025&refinements=p_27%3AWes+Mckinney&s=books&sr=1-1&ufe=app_do%3Aamzn1.fos.6121c6c4-c969-43ae-92f7-cc248fc6181d&tag=hallpaz-20)
#   * [Data Manipulation with Pandas](https://jakevdp.github.io/PythonDataScienceHandbook/03.00-introduction-to-pandas.html)
#
# 3. Aulas em vídeo
#   * [Dicas de Pandas](https://www.youtube.com/watch?v=MVd1cs7TDgA&list=PL5TJqBvpXQv6SSsEgQrNwpOLTupXPuiMQ)
#   * [Introdução à análise de dados](https://www.youtube.com/watch?v=RlGOaSPFtXc&list=PL5TJqBvpXQv5N3iV68bGBkea0HjMk98lR)
#   * Alura

# %% [markdown]
# # O que você precisa saber sobre Pandas?

# %% [markdown]
# * Criação de objetos
# * Entrada e saída de dados
# * Visualizando dados
# * Gráficos
# * Seleção
# * Operações
# * Agregações e Junções (Merge vs Join)
# * Agrupamento (Grouping)
# * Remodelagem
# * Dados ausentes
# * Séries Temporais
# * Categóricos
# * Lidando com Erros

# %% [markdown]
# #### Comece o quanto antes! Como? Pense em uma tarefa ou projeto! Ou tente reproduzir algo!

# %% [markdown]
# * DADOS GRATUITOS para INSPIRAR seu portfolio de Cientista de Dados INICIANTE. [Assista aqui](https://youtu.be/Nj57VD3xKdk)
#
# * 5 projetos para um portfólio de CIENTISTA DE DADOS Iniciante. [Assista aqui](https://youtu.be/a0nY4BQzxjA)

# %% [markdown]
# ### 🚨 Se ficar muito difícil, dê alguns passos para trás!

# %% [markdown]
# * Crie um plano de estudos adequado para suas necessidades! [Como criar um plano de estudos?](https://youtu.be/o8NpsLSkKUo)
#
# * Aprender [Python do ZERO do jeito certo](http://go.pgdinamica.com/pythondojeitocerto)
# * Aprender Estatística básica
#   [Curso online gratuito](https://www.youtube.com/watch?v=5KPIwXWizCA&list=PLQcLb-PUD9WNZnVBYDKEonioyJw3nEaOM)

# %% [markdown]
# # Pandas na Prática

# %% [markdown]
# ## Instalação
#
# >Depende do ambiente!

# %%
# !pip install pandas

# %%
import pandas
pandas.__version__
# Out:
# '1.1.5'

# %% [markdown]
# ## Convenção de importação

# %%
import pandas as pd

# %%
pd?

# %% [markdown]
# ## As duas principais estruturas de dados do Pandas

# %% [markdown]
# Que tipo de dados os pandas manipulam?

# %% [markdown]
# ### Series

# %% [markdown]
# ![Series](https://pandas.pydata.org/pandas-docs/stable/_images/01_table_series.svg)

# %% [markdown]
# Series é uma matriz rotulada unidimensional capaz de conter qualquer tipo de dados (inteiros, strings, números de ponto flutuante, objetos Python, etc.) Os rótulos dos eixos são chamados coletivamente de índice. O método básico para criar uma série é:

# %%
 s1 = pd.Series(['a','b','c','d'], index= [1,2,3,4], name='Random')
 s2 = pd.Series(['e','f','g','h'], index= [1,2,3,4], name='Random2')

# %% [markdown]
# ### Dataframes

# %% [markdown]
# ![Dataframe](https://pandas.pydata.org/pandas-docs/stable/_images/01_table_dataframe.svg)

# %% [markdown]
# DataFrame é uma estrutura de dados rotulada bidimensional com colunas de tipos potencialmente diferentes. Você pode pensar nisso como uma planilha ou tabela SQL, ou um dicionário de objetos Series. Geralmente é o objeto pandas mais comumente usado. Como o Series, o DataFrame aceita muitos tipos diferentes de entrada:
#
# * Dict of 1D ndarrays, listas, dicts ou Series
#
# * 2-D numpy.ndarray
#
# * Ndarray estruturado ou de registro
#
# * UMA Series
#
# * Outro DataFrame

# %%
pd.DataFrame([s1,s2])
# Out:
#          1  2  3  4
# Random   a  b  c  d
# Random2  e  f  g  h

# %% [markdown]
# ## Abrindo e exportado dados

# %%
covid = pd.read_csv("/content/drive/MyDrive/Colab Datasets/HIST_PAINEL_COVIDBR_09mai2021.csv", sep=';')

# %%
# covid.to_csv("covid.csv")

# %%
municipios = pd.read_csv("/content/drive/MyDrive/Colab Datasets/MC01/brasil-municipios.csv")

# %% [markdown]
# ## Visualizando dados

# %% [markdown]
# * head
# * tail
# * index
# * columns
# * describe
# * transposta

# %%
covid.head()
# Out:
#    regiao estado  ... emAcompanhamentoNovos  interior/metropolitana
# 0  Brasil    NaN  ...                   NaN                     NaN
# 1  Brasil    NaN  ...                   NaN                     NaN
# 2  Brasil    NaN  ...                   NaN                     NaN
# 3  Brasil    NaN  ...                   NaN                     NaN
# 4  Brasil    NaN  ...                   NaN                     NaN
#
# [5 rows x 17 columns]

# %%
covid[covid.municipio.isnull()== False]
# Out:
#                regiao estado  ... emAcompanhamentoNovos  interior/metropolitana
# 12731           Norte     RO  ...                   NaN                     0.0
# 12732           Norte     RO  ...                   NaN                     0.0
# 12733           Norte     RO  ...                   NaN                     0.0
# 12734           Norte     RO  ...                   NaN                     0.0
# 12735           Norte     RO  ...                   NaN                     0.0
# ...               ...    ...  ...                   ...                     ...
# 2299036  Centro-Oeste     DF  ...                   NaN                     1.0
# 2299037  Centro-Oeste     DF  ...                   NaN                     1.0
# 2299038  Centro-Oeste     DF  ...                   NaN                     1.0
# 2299039  Centro-Oeste     DF  ...                   NaN                     1.0
# 2299040  Centro-Oeste     DF  ...                   NaN                     1.0
#
# ...

# %%
municipios.head()
# Out:
#    codigo_ibge                 nome  latitude  longitude  capital  codigo_uf
# 0      5200050      Abadia de Goiás -16.75730   -49.4412        0         52
# 1      3100104  Abadia dos Dourados -18.48310   -47.3916        0         31
# 2      5200100            Abadiânia -16.19700   -48.7057        0         52
# 3      3100203               Abaeté -19.15510   -45.4444        0         31
# 4      1500107           Abaetetuba  -1.72183   -48.8788        0         15

# %%
covid.tail()
# Out:
#                regiao estado  ... emAcompanhamentoNovos  interior/metropolitana
# 2299036  Centro-Oeste     DF  ...                   NaN                     1.0
# 2299037  Centro-Oeste     DF  ...                   NaN                     1.0
# 2299038  Centro-Oeste     DF  ...                   NaN                     1.0
# 2299039  Centro-Oeste     DF  ...                   NaN                     1.0
# 2299040  Centro-Oeste     DF  ...                   NaN                     1.0
#
# [5 rows x 17 columns]

# %%
covid.columns
# Out:
# Index(['regiao', 'estado', 'municipio', 'coduf', 'codmun', 'codRegiaoSaude',
#        'nomeRegiaoSaude', 'data', 'semanaEpi', 'populacaoTCU2019',
#        'casosAcumulado', 'casosNovos', 'obitosAcumulado', 'obitosNovos',
#        'Recuperadosnovos', 'emAcompanhamentoNovos', 'interior/metropolitana'],
#       dtype='object')

# %%
covid.columns.values
# Out:
# array(['regiao', 'estado', 'municipio', 'coduf', 'codmun',
#        'codRegiaoSaude', 'nomeRegiaoSaude', 'data', 'semanaEpi',
#        'populacaoTCU2019', 'casosAcumulado', 'casosNovos',
#        'obitosAcumulado', 'obitosNovos', 'Recuperadosnovos',
#        'emAcompanhamentoNovos', 'interior/metropolitana'], dtype=object)

# %%
covid.describe()
# Out:
#               coduf  ...  interior/metropolitana
# count  2.299041e+06  ...            2.278130e+06
# mean   3.235983e+01  ...            6.929982e-02
# std    9.876021e+00  ...            2.539634e-01
# min    1.100000e+01  ...            0.000000e+00
# 25%    2.500000e+01  ...            0.000000e+00
# 50%    3.100000e+01  ...            0.000000e+00
# 75%    4.100000e+01  ...            0.000000e+00
# max    7.600000e+01  ...            1.000000e+00
#
# [8 rows x 12 columns]

# %%
covid.T
# Out:
#                             0        ...           2299040
# regiao                       Brasil  ...      Centro-Oeste
# estado                          NaN  ...                DF
# municipio                       NaN  ...          Brasília
# coduf                            76  ...                53
# codmun                          NaN  ...            530010
# codRegiaoSaude                  NaN  ...             53001
# nomeRegiaoSaude                 NaN  ...  DISTRITO FEDERAL
# data                     2020-02-25  ...        2021-05-09
# semanaEpi                         9  ...                19
# populacaoTCU2019        2.10147e+08  ...       3.01527e+06
# casosAcumulado                    0  ...            386688
# casosNovos                        0  ...               925
# obitosAcumulado                   0  ...              8113
# obitosNovos                       0  ...                26
# Recuperadosnovos                NaN  ...               NaN
# ...

# %% [markdown]
# ## Selecionando dados

# %%
covid[5:10]
# Out:
#    regiao estado  ... emAcompanhamentoNovos  interior/metropolitana
# 5  Brasil    NaN  ...                   NaN                     NaN
# 6  Brasil    NaN  ...                   NaN                     NaN
# 7  Brasil    NaN  ...                   NaN                     NaN
# 8  Brasil    NaN  ...                   NaN                     NaN
# 9  Brasil    NaN  ...                   NaN                     NaN
#
# [5 rows x 17 columns]

# %%
covid["regiao"]
# Out:
# 0                Brasil
# 1                Brasil
# 2                Brasil
# 3                Brasil
# 4                Brasil
#                ...
# 2299036    Centro-Oeste
# 2299037    Centro-Oeste
# 2299038    Centro-Oeste
# 2299039    Centro-Oeste
# 2299040    Centro-Oeste
# Name: regiao, Length: 2299041, dtype: object

# %%
covid[["regiao","estado"]]
# Out:
#                regiao estado
# 0              Brasil    NaN
# 1              Brasil    NaN
# 2              Brasil    NaN
# 3              Brasil    NaN
# 4              Brasil    NaN
# ...               ...    ...
# 2299036  Centro-Oeste     DF
# 2299037  Centro-Oeste     DF
# 2299038  Centro-Oeste     DF
# 2299039  Centro-Oeste     DF
# 2299040  Centro-Oeste     DF
#
# [2299041 rows x 2 columns]

# %%
covid.loc[1000:2000,["estado","municipio"]]
# Out:
#      estado municipio
# 1000     AC       NaN
# 1001     AC       NaN
# 1002     AC       NaN
# 1003     AC       NaN
# 1004     AC       NaN
# ...     ...       ...
# 1996     RR       NaN
# 1997     RR       NaN
# 1998     RR       NaN
# 1999     RR       NaN
# 2000     RR       NaN
#
# [1001 rows x 2 columns]

# %%
covid.iloc[1000]
# Out:
# regiao                         Norte
# estado                            AC
# municipio                        NaN
# coduf                             12
# codmun                           NaN
# codRegiaoSaude                   NaN
# nomeRegiaoSaude                  NaN
# data                      2020-06-22
# semanaEpi                         26
# populacaoTCU2019              881935
# casosAcumulado                 11539
# casosNovos                       158
# obitosAcumulado                  305
# obitosNovos                        5
# Recuperadosnovos                 NaN
# emAcompanhamentoNovos            NaN
# interior/metropolitana           NaN
# Name: 1000, dtype: object

# %%
covid.iloc[50:100,2:4]
# Out:
#    municipio  coduf
# 50       NaN     76
# 51       NaN     76
# 52       NaN     76
# 53       NaN     76
# 54       NaN     76
# 55       NaN     76
# 56       NaN     76
# 57       NaN     76
# 58       NaN     76
# 59       NaN     76
# 60       NaN     76
# 61       NaN     76
# 62       NaN     76
# 63       NaN     76
# 64       NaN     76
# 65       NaN     76
# 66       NaN     76
# 67       NaN     76
# 68       NaN     76
# 69       NaN     76
# 70       NaN     76
# 71       NaN     76
# 72       NaN     76
# 73       NaN     76
# 74       NaN     76
# 75       NaN     76
# 76       NaN     76
# 77       NaN     76
# 78       NaN     76
# 79       NaN     76
# 80       NaN     76
# 81       NaN     76
# 82       NaN     76
# 83       NaN     76
# 84       NaN     76
# 85       NaN     76
# 86       NaN     76
# 87       NaN     76
# 88       NaN     76
# 89       NaN     76
# 90       NaN     76
# 91       NaN     76
# 92       NaN     76
# 93       NaN     76
# ...

# %%
covid.select_dtypes("float")
# Out:
#            codmun  ...  interior/metropolitana
# 0             NaN  ...                     NaN
# 1             NaN  ...                     NaN
# 2             NaN  ...                     NaN
# 3             NaN  ...                     NaN
# 4             NaN  ...                     NaN
# ...           ...  ...                     ...
# 2299036  530010.0  ...                     1.0
# 2299037  530010.0  ...                     1.0
# 2299038  530010.0  ...                     1.0
# 2299039  530010.0  ...                     1.0
# 2299040  530010.0  ...                     1.0
#
# [2299041 rows x 6 columns]

# %% [markdown]
# ## Indexação Booleana

# %%
covid[covid['coduf'] > 22]
# Out:
#                regiao estado  ... emAcompanhamentoNovos  interior/metropolitana
# 0              Brasil    NaN  ...                   NaN                     NaN
# 1              Brasil    NaN  ...                   NaN                     NaN
# 2              Brasil    NaN  ...                   NaN                     NaN
# 3              Brasil    NaN  ...                   NaN                     NaN
# 4              Brasil    NaN  ...                   NaN                     NaN
# ...               ...    ...  ...                   ...                     ...
# 2299036  Centro-Oeste     DF  ...                   NaN                     1.0
# 2299037  Centro-Oeste     DF  ...                   NaN                     1.0
# 2299038  Centro-Oeste     DF  ...                   NaN                     1.0
# 2299039  Centro-Oeste     DF  ...                   NaN                     1.0
# 2299040  Centro-Oeste     DF  ...                   NaN                     1.0
#
# ...

# %%
covid[(covid['coduf'] > 22) & (covid['coduf'] < 42 )]
# Out:
#            regiao estado  ... emAcompanhamentoNovos  interior/metropolitana
# 4402     Nordeste     CE  ...                   NaN                     NaN
# 4403     Nordeste     CE  ...                   NaN                     NaN
# 4404     Nordeste     CE  ...                   NaN                     NaN
# 4405     Nordeste     CE  ...                   NaN                     NaN
# 4406     Nordeste     CE  ...                   NaN                     NaN
# ...           ...    ...  ...                   ...                     ...
# 1782469       Sul     PR  ...                   NaN                     0.0
# 1782470       Sul     PR  ...                   NaN                     0.0
# 1782471       Sul     PR  ...                   NaN                     0.0
# 1782472       Sul     PR  ...                   NaN                     0.0
# 1782473       Sul     PR  ...                   NaN                     0.0
#
# [1408968 rows x 17 columns]

# %%
covid[covid['estado'] == 'CE'].shape[0]
# Out:
# 76105

# %% [markdown]
# ## Operações

# %% [markdown]
# * [unique](https://pandas.pydata.org/docs/reference/api/pandas.Series.unique.html?)
# * [mean](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mean.html)
# * [apply](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.apply.html)
# * [value_counts](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.value_counts.html)
# * [sort_values](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html)

# %%
covid['estado'].unique()
# Out:
# array([nan, 'RO', 'AC', 'AM', 'RR', 'PA', 'AP', 'TO', 'MA', 'PI', 'CE',
#        'RN', 'PB', 'PE', 'AL', 'SE', 'BA', 'MG', 'ES', 'RJ', 'SP', 'PR',
#        'SC', 'RS', 'MS', 'MT', 'GO', 'DF'], dtype=object)

# %%
covid['casosNovos'].mean()
# Out:
# 19.814509615096032

# %%
covid['estado'].value_counts()
# Out:
# MG    349726
# SP    264654
# RS    204122
# BA    171402
# PR    164040
# SC    121504
# GO    101463
# PI     92465
# PB     92056
# MA     89602
# PE     76514
# CE     76105
# RN     69152
# PA     59336
# MT     58518
# TO     57700
# AL     42567
# RJ     38477
# MS     32751
# ES     32751
# SE     31524
# AM     25798
# RO     22117
# AC      9438
# AP      6984
# RR      6984
# DF       849
# Name: estado, dtype: int64

# %%
covid['estado'].value_counts(normalize=True)
# Out:
# MG    0.152147
# SP    0.115137
# RS    0.088803
# BA    0.074568
# PR    0.071365
# SC    0.052860
# GO    0.044141
# PI    0.040227
# PB    0.040049
# MA    0.038981
# PE    0.033287
# CE    0.033109
# RN    0.030084
# PA    0.025814
# MT    0.025458
# TO    0.025102
# AL    0.018519
# RJ    0.016739
# MS    0.014248
# ES    0.014248
# SE    0.013714
# AM    0.011223
# RO    0.009622
# AC    0.004106
# AP    0.003038
# RR    0.003038
# DF    0.000369
# Name: estado, dtype: float64

# %%
covid[["casosNovos", "obitosNovos"]].apply(lambda x: x.max())
# Out:
# casosNovos     100.158
# obitosNovos      4.249
# dtype: float64

# %%
covid['coduf'].sort_values(ascending=True)
# Out:
# 24977    11
# 20749    11
# 20748    11
# 20747    11
# 20746    11
#          ..
# 299      76
# 300      76
# 301      76
# 290      76
# 0        76
# Name: coduf, Length: 2299041, dtype: int64

# %%
covid.sort_values(by=['obitosNovos','casosNovos'], ascending=True)
# Out:
#                regiao estado  ... emAcompanhamentoNovos  interior/metropolitana
# 935158        Sudeste     MG  ...                   NaN                     NaN
# 2155583  Centro-Oeste     MT  ...                   NaN                     0.0
# 2155173  Centro-Oeste     MT  ...                   NaN                     1.0
# 1336527       Sudeste     RJ  ...                   NaN                     1.0
# 2415            Norte     PA  ...                   NaN                     NaN
# ...               ...    ...  ...                   ...                     ...
# 415            Brasil    NaN  ...             1166771.0                     NaN
# 409            Brasil    NaN  ...             1188271.0                     NaN
# 402            Brasil    NaN  ...             1257295.0                     NaN
# 408            Brasil    NaN  ...             1204849.0                     NaN
# 410            Brasil    NaN  ...             1202639.0                     NaN
#
# ...

# %% [markdown]
# ### Gráficos
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html#visualization

# %%
covid['estado'].value_counts().plot(kind='bar')

# %%
covid['coduf'].plot(kind='hist')

# %% [markdown]
# ## Agrupamento (Group By)

# %%
covid.groupby(['estado']).mean()
# Out:
#         coduf         codmun  ...  emAcompanhamentoNovos  interior/metropolitana
# estado                        ...
# AC       12.0  120034.636364  ...                    NaN                0.045455
# AL       27.0  270473.262136  ...                    NaN                0.117647
# AM       13.0  130216.419355  ...                    NaN                0.209677
# AP       16.0  160036.500000  ...                    NaN                0.187500
# BA       29.0  291710.490431  ...                    NaN                0.031175
# CE       23.0  230699.637838  ...                    NaN                0.103261
# DF       53.0  530010.000000  ...                    NaN                1.000000
# ES       32.0  320286.531646  ...                    NaN                0.089744
# GO       52.0  521128.599190  ...                    NaN                0.085366
# MA       21.0  210643.674312  ...                    NaN                0.059908
# ...

# %% [markdown]
# ## Valores ausentes

# %% [markdown]
# Métodos   | Descrição
# :--------- | :------
# *isnull( )* | Gere uma máscara booleana indicando valores ausentes
# *notnull( )* | Oposto de isnull()
# *dropna( )* | Retorna uma versão filtrada dos dados
# *fillna( )* | Retorna uma cópia dos dados com os valores ausentes preenchidos ou imputados

# %%
YouTubeVideo("Itin6sBj49k", width=640)

# %%
covid[covid.municipio.isnull()== False]
# Out:
#                regiao estado  ... emAcompanhamentoNovos  interior/metropolitana
# 12731           Norte     RO  ...                   NaN                     0.0
# 12732           Norte     RO  ...                   NaN                     0.0
# 12733           Norte     RO  ...                   NaN                     0.0
# 12734           Norte     RO  ...                   NaN                     0.0
# 12735           Norte     RO  ...                   NaN                     0.0
# ...               ...    ...  ...                   ...                     ...
# 2299036  Centro-Oeste     DF  ...                   NaN                     1.0
# 2299037  Centro-Oeste     DF  ...                   NaN                     1.0
# 2299038  Centro-Oeste     DF  ...                   NaN                     1.0
# 2299039  Centro-Oeste     DF  ...                   NaN                     1.0
# 2299040  Centro-Oeste     DF  ...                   NaN                     1.0
#
# ...

# %% [markdown]
# ## Dados categóricos

# %%
YouTubeVideo("Sp9oqlVBgJc", width=640)

# %% [markdown]
# ## Lidando com erros

# %% [markdown]
# ![Captura de Tela 2021-09-04 às 14.37.12.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de Tela 2021-09-04 às 14.40.29.png](data:image/png;base64,...)
