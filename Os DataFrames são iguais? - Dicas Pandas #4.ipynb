# %% [markdown]
# ## Como saber se dois DataFrames são iguais? - Dica de Pandas #4

# %% [markdown]
# link para documentação: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.testing.assert_frame_equal.html?highlight=assert#pandas.testing.assert_frame_equal

# %%
from IPython.display import YouTubeVideo, Image

# %%
display(YouTubeVideo('a-g36QtGtOg', width=550, height=310))

# %%
display(Image(filename='../imgs/comentarioDP4.png'))

# %%
from pandas.testing import assert_frame_equal
import pandas as pd

# %%
df1 = pd.DataFrame({'a': [1, 2], 'b': [3, 4]})
df2 = pd.DataFrame({'a': [1, 2], 'b': [3.0, 4.0]})

# %%
assert_frame_equal(df1, df1)

# %%
df3 = df1

# %%
df3
# Out:
#    a  b
# 0  1  3
# 1  2  4

# %%
df1
# Out:
#    a  b
# 0  1  3
# 1  2  4

# %%
assert_frame_equal(df1, df3)

# %%
df3['c'] = [5,6]

# %%
df3
# Out:
#    a  b  c
# 0  1  3  5
# 1  2  4  6

# %%
assert_frame_equal(df1, df3)

# %%
df1
# Out:
#    a  b  c
# 0  1  3  5
# 1  2  4  6

# %%
df4 = df1.copy()

# %%
df1
# Out:
#    a  b  c
# 0  1  3  5
# 1  2  4  6

# %%
df4
# Out:
#    a  b  c
# 0  1  3  5
# 1  2  4  6

# %%
assert_frame_equal(df1, df4)

# %%
df4['d']=[7,8]

# %%
df4
# Out:
#    a  b  c  d
# 0  1  3  5  7
# 1  2  4  6  8

# %%
assert_frame_equal(df1, df4)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-21-6c630ba71d7a> in <module>
# ----> 1 assert_frame_equal(df1, df4)
#
# ~/Workspace/machine-learning/venv-ml/lib/python3.7/site-packages/pandas/util/testing.py in assert_frame_equal(left, right, check_dtype, check_index_type, check_column_type, check_frame_type, check_less_precise, check_names, by_blocks, check_exact, check_datetimelike_compat, check_categorical, check_like, obj)
#    1343             "{obj} shape mismatch".format(obj=obj),
#    1344             "{shape!r}".format(shape=left.shape),
# -> 1345             "{shape!r}".format(shape=right.shape),
#    1346         )
#    1347
#
# ~/Workspace/machine-learning/venv-ml/lib/python3.7/site-packages/pandas/util/testing.py in raise_assert_detail(obj, message, left, right, diff)
#     930         msg += "\n[diff]: {diff}".format(diff=diff)
#     931
# --> 932     raise AssertionError(msg)
#     933
#     934
#
# AssertionError: DataFrame are different
#
# DataFrame shape mismatch
# [left]:  (2, 3)
# [right]: (2, 4)

# %%
df1
# Out:
#    a  b  c
# 0  1  3  5
# 1  2  4  6
