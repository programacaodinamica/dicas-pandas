# %%
# !pip install cutecharts

# %%
import pandas as pd
import cutecharts.charts as ctc

# %%
microdados_enem_rj = pd.read_csv('../dados/microdados_enem_ufs_2019/microdados_enem_RJ_2019.csv', index_col=0)

# %%
microdados_enem_rj.head()
# Out:
#        NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 10600  190001015227    2019                  3302056                  Italva
# 21074  190001025702    2019                  3305109      São João de Meriti
# 22657  190001027285    2019                  3304557          Rio de Janeiro
# 30365  190001034993    2019                  3304557          Rio de Janeiro
# 60937  190001065566    2019                  3304557          Rio de Janeiro
#
#        CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 10600                33               RJ        32       F                1
# 21074                33               RJ        32       M                1
# 22657                33               RJ        26       M                1
# 30365                33               RJ        19       F                1
# 60937                33               RJ        22       F                1
#
# ...

# %%
microdados_enem_rj.reset_index(inplace=True,drop=True)

# %%
microdados_enem_rj
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 0       190001015227    2019                  3302056                  Italva
# 1       190001025702    2019                  3305109      São João de Meriti
# 2       190001027285    2019                  3304557          Rio de Janeiro
# 3       190001034993    2019                  3304557          Rio de Janeiro
# 4       190001065566    2019                  3304557          Rio de Janeiro
# ...              ...     ...                      ...                     ...
# 338705  190006118895    2019                  3304557          Rio de Janeiro
# 338706  190006118896    2019                  3305109      São João de Meriti
# 338707  190006118897    2019                  3304557          Rio de Janeiro
# 338708  190006118898    2019                  3300308          Barra do Piraí
# 338709  190006118899    2019                  3304904             São Gonçalo
#
# ...

# %%
microdados_enem_rj.SG_UF_RESIDENCIA.unique()
# Out:
# array(['RJ'], dtype=object)

# %%
microdados_enem_rj.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
#        'TP_NACIONALIDADE', 'CO_MUNICIPIO_NASCIMENTO',
#        'NO_MUNICIPIO_NASCIMENTO', 'CO_UF_NASCIMENTO', 'SG_UF_NASCIMENTO',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_ESCOLA', 'CO_MUNICIPIO_ESC',
#        'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC',
#        'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC',
#        'IN_BAIXA_VISAO', 'IN_CEGUEIRA', 'IN_SURDEZ',
#        'IN_DEFICIENCIA_AUDITIVA', 'IN_SURDO_CEGUEIRA',
#        'IN_DEFICIENCIA_FISICA', 'IN_DEFICIENCIA_MENTAL',
#        'IN_DEFICIT_ATENCAO', 'IN_DISLEXIA', 'IN_DISCALCULIA',
#        'IN_AUTISMO', 'IN_VISAO_MONOCULAR', 'IN_OUTRA_DEF', 'IN_GESTANTE',
#        'IN_LACTANTE', 'IN_IDOSO', 'IN_ESTUDA_CLASSE_HOSPITALAR',
# ...

# %%
microdados_enem_rj[['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
       'NU_NOTA_MT']].mean()
# Out:
# NU_NOTA_CN    491.892385
# NU_NOTA_CH    523.361916
# NU_NOTA_LC    535.900530
# NU_NOTA_MT    539.564877
# dtype: float64

# %%
chart = ctc.Bar('Médias Notas RJ',width='500px',height='400px')
chart.set_options(
 labels=['C. Natureza', 'C. Humanas', 'Linguagens', 'Matemática', 'Redação'],
 x_label="Provas",
 y_label="Média por Prova" ,
 colors=['#D9F1BB','#F7B7A3','#EA5F89','#9B3192', '#FFFF77']
 )
chart.add_series("Média",list(microdados_enem_rj[['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
       'NU_NOTA_MT', 'NU_NOTA_REDACAO']].mean()))
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'chartXkcd':'https://cdn.jsdelivr.net/npm/chart.xkcd@1.1/dist/chart.xkcd.min'
#         }
#     });
# </script>
#
# <div id="6fee3606ed0f437b842f6893bd4b8c8c" class="chart-container" style="width: 500px">
#         <svg id="chart_6fee3606ed0f437b842f6893bd4b8c8c"></svg>
#     </div>
#     <script>
#         require(['chartXkcd'], function(chartXkcd) {
#             const svg_6fee3606ed0f437b842f6893bd4b8c8c = document.querySelector('#chart_6fee3606ed0f437b842f6893bd4b8c8c')
# ...

# %%
municipio = "Angra dos Reis"

radar_chart = ctc.Radar('Médias Notas RJ',width='600px',height='600px')
radar_chart.set_options(
 labels=['C. Natureza', 'C. Humanas', 'Linguagens', 'Matemática'],
 is_show_legend=True, #by default, it is true. You can turn it off.
 legend_pos='upRight'  #location of the legend
 )

radar_chart.add_series("Média dos Municípios RJ",list(microdados_enem_rj[['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
       'NU_NOTA_MT','NU_NOTA_REDACAO']].mean()))
radar_chart.add_series("Média do Município {}".format(municipio),
                       list(microdados_enem_rj.groupby(['NO_MUNICIPIO_RESIDENCIA'])['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
       'NU_NOTA_MT','NU_NOTA_REDACAO'].mean().loc[municipio]))

radar_chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'chartXkcd':'https://cdn.jsdelivr.net/npm/chart.xkcd@1.1/dist/chart.xkcd.min'
#         }
#     });
# </script>
#
# <div id="bf7b051deeac406281522541fe2a8080" class="chart-container" style="width: 600px">
#         <svg id="chart_bf7b051deeac406281522541fe2a8080"></svg>
#     </div>
#     <script>
#         require(['chartXkcd'], function(chartXkcd) {
#             const svg_bf7b051deeac406281522541fe2a8080 = document.querySelector('#chart_bf7b051deeac406281522541fe2a8080')
# ...

# %%
microdados_enem_rj.groupby(['NO_MUNICIPIO_RESIDENCIA'])['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
       'NU_NOTA_MT'].mean().loc['Angra dos Reis']
# Out:
# NU_NOTA_CN    475.984038
# NU_NOTA_CH    508.694181
# NU_NOTA_LC    527.015926
# NU_NOTA_MT    520.845753
# Name: Angra dos Reis, dtype: float64

# %%
microdados_enem_rj.groupby(['NO_MUNICIPIO_RESIDENCIA'])['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
       'NU_NOTA_MT'].mean()
# Out:
#                          NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT
# NO_MUNICIPIO_RESIDENCIA
# Angra dos Reis           475.984038  508.694181  527.015926  520.845753
# Aperibé                  493.393789  518.341379  528.701724  542.992547
# Araruama                 488.075321  514.994308  529.860574  532.785762
# Areal                    474.303145  503.188304  523.457895  515.313208
# Armação dos Búzios       490.474903  525.274910  535.007040  530.700000
# ...                             ...         ...         ...         ...
# Três Rios                482.053123  511.984375  527.105288  522.841703
# Valença                  495.254925  522.922297  534.024662  546.180657
# Varre-Sai                492.420492  503.276692  512.384211  534.113934
# Vassouras                485.166593  513.554167  528.432917  525.596239
# Volta Redonda            507.400156  535.504062  544.084667  569.327552
#
# [92 rows x 4 columns]
