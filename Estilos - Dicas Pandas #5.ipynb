# %% [markdown]
# ## Estilos no DataFrame - Dica de Pandas #5

# %% [markdown]
# link para documentação: https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html

# %%
from IPython.display import YouTubeVideo, Image

# %%
display(YouTubeVideo('8Yi3T_CeA9E', width=550, height=310))

# %%
display(Image(filename='../imgs/comentarioDP5.png'))

# %%
import pandas as pd

# %%
pd.set_option("display.max_rows", 101)

# %%
df_covid = pd.read_csv("../dados/arquivo_geral.csv", sep=';')

# %%
df_covid.head()
# Out:
#   regiao estado        data  casosNovos  casosAcumulados  obitosNovos  \
# 0  Norte     RO  2020-01-30           0                0            0
# 1  Norte     RO  2020-01-31           0                0            0
# 2  Norte     RO  2020-02-01           0                0            0
# 3  Norte     RO  2020-02-02           0                0            0
# 4  Norte     RO  2020-02-03           0                0            0
#
#    obitosAcumulados
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
df_covid_rj = df_covid[df_covid.estado == 'RJ'].tail(30)

# %%
df_covid_rj.style.highlight_min()
# Out:
# <style  type="text/css" >
#     #T_15268cae_a485_11ea_9e3f_8c8590910492row0_col4 {
#             background-color:  yellow;
#         }    #T_15268cae_a485_11ea_9e3f_8c8590910492row0_col6 {
#             background-color:  yellow;
#         }    #T_15268cae_a485_11ea_9e3f_8c8590910492row1_col5 {
#             background-color:  yellow;
#         }    #T_15268cae_a485_11ea_9e3f_8c8590910492row14_col3 {
#             background-color:  yellow;
# ...

# %%
df_covid_rj.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_153c0d72_a485_11ea_9e3f_8c8590910492row0_col3 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_153c0d72_a485_11ea_9e3f_8c8590910492row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_153c0d72_a485_11ea_9e3f_8c8590910492row0_col5 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_153c0d72_a485_11ea_9e3f_8c8590910492row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_153c0d72_a485_11ea_9e3f_8c8590910492row1_col3 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_153c0d72_a485_11ea_9e3f_8c8590910492row1_col4 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_153c0d72_a485_11ea_9e3f_8c8590910492row1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
# ...

# %%
df_covid_rj.style.set_properties(**{'background-color': 'black',
                           'color': 'white',
                           'border-color': 'white'})
# Out:
# <style  type="text/css" >
#     #T_154cdf12_a485_11ea_9e3f_8c8590910492row0_col0 {
#             background-color:  black;
#             color:  white;
#             border-color:  white;
#         }    #T_154cdf12_a485_11ea_9e3f_8c8590910492row0_col1 {
#             background-color:  black;
#             color:  white;
#             border-color:  white;
#         }    #T_154cdf12_a485_11ea_9e3f_8c8590910492row0_col2 {
#             background-color:  black;
#             color:  white;
#             border-color:  white;
#         }    #T_154cdf12_a485_11ea_9e3f_8c8590910492row0_col3 {
#             background-color:  black;
#             color:  white;
#             border-color:  white;
#         }    #T_154cdf12_a485_11ea_9e3f_8c8590910492row0_col4 {
#             background-color:  black;
#             color:  white;
#             border-color:  white;
#         }    #T_154cdf12_a485_11ea_9e3f_8c8590910492row0_col5 {
#             background-color:  black;
# ...

# %%
df_covid_rj.style.set_table_styles(
    [{'selector': 'tr:hover',
      'props': [('background-color', 'red'),('color','white')]}]
)
# Out:
# <style  type="text/css" >
#     #T_1550d338_a485_11ea_9e3f_8c8590910492 tr:hover {
#           background-color: red;
#           color: white;
#     }</style><table id="T_1550d338_a485_11ea_9e3f_8c8590910492" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >regiao</th>        <th class="col_heading level0 col1" >estado</th>        <th class="col_heading level0 col2" >data</th>        <th class="col_heading level0 col3" >casosNovos</th>        <th class="col_heading level0 col4" >casosAcumulados</th>        <th class="col_heading level0 col5" >obitosNovos</th>        <th class="col_heading level0 col6" >obitosAcumulados</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1550d338_a485_11ea_9e3f_8c8590910492level0_row0" class="row_heading level0 row0" >1889</th>
#                         <td id="T_1550d338_a485_11ea_9e3f_8c8590910492row0_col0" class="data row0 col0" >Sudeste</td>
# ...
